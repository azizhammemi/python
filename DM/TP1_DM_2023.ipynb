# %% [markdown]
# ## **Fouille de données (2023-2024)**
#
# ### **Travaux pratiques n°1**
#
# ---

# %% [markdown]
# **Importation des bibliothèques**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
df1=pd.DataFrame([[3,5,1],[20,33,21]], columns=["A", "B", "C"])
df2=df1. rename(columns={'A' :0, 'B':2, 'C' :3})
df=pd.concat([df1,df2], axis=0)
print (df. shape)
# Out:
# (4, 6)

# %% [markdown]
# ---
# ### **<u><font color='red'>Exercice 1</font></u>** Calcul Scientifique avec $numpy$
# ---

# %%
T = np.array([[15, 27],[ 36, 41],[ 12, 6]])
print(T)
print()
# Out:
# [[15 27]
#  [36 41]
#  [12  6]]

# %% [markdown]
# **1/** Remplacer tous les éléments pairs du tableau 𝐚𝐫𝐫 par $-1$

# %%
T1=np.where(arr % 2 == 0,-1,arr)
print(T1)
# Out:
# [15 27 -1 -1 41 -1 -1 95 -1 -1]

# %% [markdown]
# **2/** Modifier la taille de 𝐚𝐫𝐫 en (𝟐, 𝟓), puis concaténer-le par colonne avec le tableau *ndarray* suivant $[10, -10]$

# %%
arr=arr.reshape(2,5)
print(arr)
# Out:
# [[15 27  8 36 41]
#  [12  6 95 18 50]]

# %% [markdown]
# **3/** Trouver l’indice de l’élément maximum dans le tableau concaténé

# %%
max=np.argmax(arr)
indesmax=np.unravel_index(max,arr.shape)
print(indesmax)
# Out:
# (1, 2)

# %% [markdown]
# **4/** Diviser le tableau concaténé par ligne en deux nouveaux tableaux, 𝐚𝐫𝐫𝟏 et 𝐚𝐫𝐫𝟐, chacun de taille (𝟏, 𝟔)

# %%
arr1 = arr[0,:]
arr2 = arr[1, :]
print("arr1:", arr1)
print("arr2:", arr2)
# Out:
# arr1: [15 27  8 36 41]
# arr2: [12  6 95 18 50]

# %% [markdown]
# ---
# ### **<u><font color='red'>Exercice 2</font></u>** Exploration des données avec $pandas$
# ---

# %%
biens=np.array([[85,120],[100,200],[85,150],[200,180], [100,420],[300,330],[400,400]])

# %% [markdown]
# **1/** Générer un DataFrame à partir de **biens**,$df\_biens$, possédant $2$ colonnes, nommées respectivement **surface** et **prix**. Afficher les $5$ premières lignes de $df\_biens$

# %%
df_biens = pd.DataFrame(biens, columns = ['surface','prix'])
df_biens
# Out:
#    surface  prix
# 0       85   120
# 1      100   200
# 2       85   150
# 3      200   180
# 4      100   420
# 5      300   330
# 6      400   400

# %% [markdown]
# **2/** Afficher les surfaces des biens ayant un **prix** supérieur ou égal à $300$

# %%
df_biens.loc[df_biens['prix'] >= 300, 'surface']
# Out:
# 4    100
# 5    300
# 6    400
# Name: surface, dtype: int64

# %% [markdown]
# **3/** 	Créer une nouvelle colonne, nommée **total**, à la fin de $df\_biens$ contenant les <u>prix totaux</u> des biens. Renommer la colonne **total** par **prixT**

# %%
df_biens['total']=df_biens['surface']*df_biens['prix']
df_biens
# Out:
#    surface  prix   total
# 0       85   120   10200
# 1      100   200   20000
# 2       85   150   12750
# 3      200   180   36000
# 4      100   420   42000
# 5      300   330   99000
# 6      400   400  160000

# %% [markdown]
# **4/** 	Créer une nouvelle colonne, nommée **catégorie**, à la fin de $df\_biens$ qui prend la valeur **'B'** si **prixT** est inférieur ou égal à $32400$ et la surface est strictement inférieure à $120$, et **'A'** dans le cas contraire

# %%
df_biens['categorie'] = np.where((df_biens['prix'] <= 32400) & (df_biens['surface']> 120), 'b','a')
df_biens
# Out:
#    surface  prix   total categorie
# 0       85   120   10200         a
# 1      100   200   20000         a
# 2       85   150   12750         a
# 3      200   180   36000         b
# 4      100   420   42000         a
# 5      300   330   99000         b
# 6      400   400  160000         b

# %% [markdown]
# [texte du lien](https://)**5/** Supprimer la colonne **surface** de $df\_biens$

# %%
del df_biens['surface']
df_biens
# Out:
#    prix   total categorie
# 0   120   10200         a
# 1   200   20000         a
# 2   150   12750         a
# 3   180   36000         b
# 4   420   42000         a
# 5   330   99000         b
# 6   400  160000         b

# %% [markdown]
# :**6/** Trier les biens de 𝒅𝒇_𝒃𝒊𝒆𝒏𝒔 par ordre décroissant selon **prixT** et réinitialiser les indices des lignes

# %%
df_biens.sort_values(by='total',inplace=True,ascending=True,ignore_index=True)
df_biens
# Out:
#    surface  prix   total categorie
# 0       85   120   10200         a
# 1       85   150   12750         a
# 2      100   200   20000         a
# 3      200   180   36000         b
# 4      100   420   42000         a
# 5      300   330   99000         b
# 6      400   400  160000         b

# %% [markdown]
# ```
# # Ce texte est au format code
# ```
#
# **7/** Afficher le **prix** *le plus cher* <u>pour chaque catégorie des biens</u>

# %%
prix_max_par_categorie = df_biens.groupby('categorie')['prix'].max()
print(prix_max_par_categorie)
# Out:
# categorie
# a    420
# b    400
# Name: prix, dtype: int64

# %% [markdown]
# **8/** Exporter en **CSV** le DataFrame sous le nom ***'exercice2TP1.csv'***
#
# ---

# %%
df_biens.to_csv('exercice2TP1.csv', index=False)

# %% [markdown]
# ---
# ### **<u><font color='red'>Exercice 3</font></u>** Visualisation graphique avec $matplotlib$ \& $seaborn$
# ---

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
plt.figure(figsize=(3,2))
a=range(1,6)
b=[8, 9, 5, 6, 2]
plt.plot(a,b) # Traçage
plt.show() # Affichage
#plt.plot(b) ?

# %% [markdown]
# **1/** Charger le jeu de données **"athlete.csv"** dans un DataFrame nommé $df\_athlete$, puis afficher sa taille et les types de données de chaque attribut

# %%
df_athlete=pd.read_csv('/content/drive/MyDrive/athlete.csv', sep=",")
print(df_athlete.shape)
df_athlete
# Out:
# (213, 5)
#     Sex   Age  Height  Weight       Sport
# 0     M  24.0   180.0    80.0  Basketball
# 1     M  23.0   170.0    60.0        Judo
# 2     M  28.0   175.0    64.0  Gymnastics
# 3     M  28.0   175.0    64.0  Gymnastics
# 4     M  28.0   175.0    64.0  Gymnastics
# ..   ..   ...     ...     ...         ...
# 208   M  31.0   180.0    64.0   Athletics
# 209   M  26.0   178.0    81.0        Judo
# 210   M  33.0   182.0    77.0    Football
# 211   M  22.0   193.0    78.0   Athletics
# 212   M  25.0   186.0    84.0   Athletics
#
# [213 rows x 5 columns]

# %% [markdown]
# **2/**	Tracer une courbe montrant le poids maximum des athlètes en fonction de leur **âge**, <u>en marquant la valeur maximale des poids des athlètes ayant l’âge de $16$ ans</u>

# %%
#max=df_athlete.groupby(["Age"])["Weight"].max()
max=df_athlete[df_athlete["Age"] > 16].groupby("Age")["Weight"].max()

plt.figure(figsize=(5,3))
plt.plot(max.index,max.values)
plt.show()

# %% [markdown]
# **3/** Tracer un histogramme représentant la distribution des athlètes en fonction de $4$ intervalles d’**âge**

# %%
age_min = df_athlete["Age"].min()
age_max = df_athlete["Age"].max()
age_bins = np.linspace(age_min, age_max,5)
plt.xticks(age_bins)
print(age_bins)
sns.histplot(df_athlete["Age"], bins=age_bins)
plt.show()
# Out:
# [16.   21.25 26.5  31.75 37.  ]

# %% [markdown]
# **4/** Créer une figure de dimensions $3\times11$ pouces (**in**) comprenant $2$ axes alignés horizontalement, représentant <u>la distribution des athlètes selon leur sport</u>. Le premier axe doit afficher un **histogramme**, tandis que le deuxième doit afficher un **diagramme en secteurs**

# %%
plt.subplot(1,2,1)
sns.countplot(x = 'Sport',data=df_athlete)
plt.subplot(1,2,2)
df_athlete['Sport'].value_counts().plot.pie()
plt.tight_layout()

# %% [markdown]
# **5/**Tracer le **nuage de points** (scatter) de **Height** en fonction de **Weight** ainsi que de **Height** en fonction d’**Age**. Ajouter une légende à la figure et supprimer les titres des axis

# %%
x1 =df_athlete['Height']
x = df_athlete['Weight']
y = df_athlete['Age']
plt.scatter(x1,x)

plt.scatter(x1,y, c='cyan')
plt.legend(['C1', 'C2'], loc=0)

# %% [markdown]
# **6/** Tracer une **heatmap** représentant les <u>statistiques descriptives</u> de $df\_athlete$ pour chaque attribut (moyenne, écart-type, etc.)

# %%
df_athlete.describe()
# Out:
#               Age      Height      Weight
# count  213.000000  213.000000  213.000000
# mean    23.934272  173.577465   66.582160
# std      4.071924   10.287832   13.653359
# min     16.000000  147.000000   40.000000
# 25%     21.000000  167.000000   60.000000
# 50%     23.000000  175.000000   64.000000
# 75%     26.000000  180.000000   73.000000
# max     37.000000  205.000000  130.000000

# %%
plt.figure(figsize=(5,7))
sns.heatmap(df_athlete.describe(),annot=True,fmt='f',cbar=True)
plt.show()
